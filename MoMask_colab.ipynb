# %% [markdown]
# <a href="https://colab.research.google.com/github/firetix/AgentBookmarksOrganizer/blob/master/MoMask_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MoMask-hf
# %cd /content/MoMask-hf

# !pip install -q gradio==3.50.2 git+https://github.com/openai/CLIP einops matplotlib==3.3.4
# !pip install -q chumpy einops fastapi ffmpy ftfy gradio gradio_client h11 httpcore httpx orjson trimesh vector-quantize-pytorch

# !sh prepare/download_evaluator.sh
# !sh prepare/download_glove.sh
# !sh prepare/download_models.sh
# !sh prepare/download_models_demo.sh

# !python gen_t2m.py --gpu_id 0 --ext exp1 --text_prompt "A person is running on a treadmill."

# %cd /content/MoMask-hf
# !python app.py
# Out:
# /content
# Cloning into 'MoMask-hf'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 248 (delta 115), reused 244 (delta 113), pack-reused 0 (from 0)
# Receiving objects: 100% (248/248), 528.48 KiB | 800.00 KiB/s, done.
# Resolving deltas: 100% (115/115), done.
# Filtering content: 100% (2/2), 620.24 KiB | 461.00 KiB/s, done.
# /content/MoMask-hf
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 24.0 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# -e Downloading pretrained models for HumanML3D dataset
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1dtKP2xBk-UjG9o16MVfBJDmGNSI56Dch
#
# but Gdown can't. Please check connections and permissions.
# unzip:  cannot find or open humanml3d_models.zip, humanml3d_models.zip.zip or humanml3d_models.zip.ZIP.
# rm: cannot remove 'humanml3d_models.zip': No such file or directory
# /content/MoMask-hf
# Is CUDA available: True
# CUDA device: Tesla T4
# Traceback (most recent call last):
#   File "/content/MoMask-hf/app.py", line 18, in <module>
#     from models.mask_transformer.transformer import MaskTransformer, ResidualTransformer
#   File "/content/MoMask-hf/models/mask_transformer/transformer.py", line 6, in <module>
#     import clip
# ModuleNotFoundError: No module named 'clip'
